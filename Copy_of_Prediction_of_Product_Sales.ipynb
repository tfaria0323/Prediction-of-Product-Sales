# %% [markdown]
# <a href="https://colab.research.google.com/github/tfaria0323/Prediction-of-Product-Sales/blob/main/Copy_of_Prediction_of_Product_Sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prediction of Product Sales
#   - Tiniq Faria

# %% [markdown]
# - ## "Project Overview"

# %% [markdown]
# - ## "Load and Inspect Data"

# %%
fpath = '/content/drive/MyDrive/StudentFolders16wk24wk/CodingDojo/01-Fundamentals/Week02/Data/sales_predictions_2023.csv'
df_salepred = pd.read_csv(fpath)
df_salepred.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df_salepred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# - ## "Clean Data"

# %%
# How many rows and columns?
df_salepred.shape
# Out:
# (8523, 12)

# %%
# What are the datatypes of each variable?
df_salepred.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
# Are there duplicates? If so, drop any duplicates.
duplicated_rows = df_salepred.duplicated()
duplicated_rows
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8518    False
# 8519    False
# 8520    False
# 8521    False
# 8522    False
# Length: 8523, dtype: bool

# %%
# Identify missing values.
df_salepred.isna()
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0               False        False             False            False
# 1               False        False             False            False
# 2               False        False             False            False
# 3               False        False             False            False
# 4               False        False             False            False
# ...               ...          ...               ...              ...
# 8518            False        False             False            False
# 8519            False        False             False            False
# 8520            False        False             False            False
# 8521            False        False             False            False
# 8522            False        False             False            False
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
# Address the missing values by using a placeholder value.
df_salepred['Outlet_Size']  = df_salepred['Outlet_Size'].fillna(-1)
df_salepred['Outlet_Size'].isna().sum()
# Out:
# 0

# %%
# Confirm that there are no missing values after addressing them.
df_salepred['Outlet_Size'].value_counts()
# Out:
# Medium    2793
# -1        2410
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
# Find and fix any inconsistent categories of data (for example: fix cat, Cat, and cats so that they are consistent).
string_cols = df_salepred.select_dtypes("object").columns
string_cols
# Out:
# Index(['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type'],
#       dtype='object')

# %%
for col in string_cols:
  print(f"Value Counts for {col}")
  print(df_salepred[col].value_counts())
  print('\n')
# Out:
# Value Counts for Item_Identifier
# FDW13    10
# FDG33    10
# NCY18     9
# FDD38     9
# DRE49     9
#          ..
# FDY43     1
# FDQ60     1
# FDO33     1
# DRF48     1
# FDC23     1
# Name: Item_Identifier, Length: 1559, dtype: int64
#
#
# Value Counts for Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64
#
#
# Value Counts for Item_Type
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64
#
#
# ...

# %%
df_salepred['Item_Fat_Content'] = df_salepred['Item_Fat_Content'].replace({'LF':"Low Fat",'low fat':'Low Fat', 'reg':'Regular'})
df_salepred['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %%
# For any numerical columns, obtain the summary statistics of each (min, max, mean).
df_salepred.median()
# Out:
# <ipython-input-54-be0d39112e71>:2: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_salepred.median()
# Item_Weight                    12.600000
# Item_Visibility                 0.053931
# Item_MRP                      143.012800
# Outlet_Establishment_Year    1999.000000
# Item_Outlet_Sales            1794.331000
# dtype: float64

# %%
df_salepred.mean()
# Out:
# <ipython-input-52-583194062278>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_salepred.mean()
# Item_Weight                    12.857645
# Item_Visibility                 0.066132
# Item_MRP                      140.992782
# Outlet_Establishment_Year    1997.831867
# Item_Outlet_Sales            2181.288914
# dtype: float64

# %%
df_salepred.mode()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDG33        12.15          Low Fat              0.0
# 1           FDW13          NaN              NaN              NaN
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0  Fruits and Vegetables  172.0422            OUT027
# 1                    NaN       NaN               NaN
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                     1985.0      Medium               Tier 3
# 1                        NaN         NaN                  NaN
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1            958.752
# 1                NaN                NaN

# %% [markdown]
# - ## "Exploratory Data Analysis"

# %% [markdown]
# - ## "Feature Inspection"
